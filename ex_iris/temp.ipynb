# %%
import pandas as pd

# %%
df = pd.read_csv('iris.csv')

# %%
df.loc[[4, 81, 129], "PetalLengthCm"] = None

# %%
df.loc[[8, 30, 131], "SepalLengthCm"] = None

# %%
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    3
# SepalWidthCm     0
# PetalLengthCm    3
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.to_csv('iris_sujo.csv')
