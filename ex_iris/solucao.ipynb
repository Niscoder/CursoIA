# %%
import pandas as pd

# %%
df_original = pd.read_csv('iris_sujo.csv')

# %%
df_original.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  147 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  147 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    str
# dtypes: float64(4), int64(1), str(1)
# memory usage: 7.2 KB

# %%
df_original.isna().sum()
# Out:
# Id               0
# SepalLengthCm    3
# SepalWidthCm     0
# PetalLengthCm    3
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df_original = df_original.drop(columns="Id")

# %%
df_original.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            NaN           0.2  Iris-setosa

# %%
df_original.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
df_original["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df_original.boxplot(by="Species", column="SepalLengthCm")
# Out:
# <Axes: title={'center': 'SepalLengthCm'}, xlabel='Species'>

# %%
df_original.boxplot(by="Species", column="SepalWidthCm")
# Out:
# <Axes: title={'center': 'SepalWidthCm'}, xlabel='Species'>

# %%
df_original.boxplot(by="Species", column="PetalLengthCm")
# Out:
# <Axes: title={'center': 'PetalLengthCm'}, xlabel='Species'>

# %%
df_original.boxplot(by="Species", column="PetalWidthCm")
# Out:
# <Axes: title={'center': 'PetalWidthCm'}, xlabel='Species'>

# %%
df_original.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     147.000000    150.000000     147.000000    150.000000
# mean        5.846259      3.054000       3.761224      1.198667
# std         0.805654      0.433594       1.763653      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.400000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.700000      4.400000       6.900000      2.500000

# %%
df_setosa = df_original[df_original["Species"] == "Iris-setosa"]
df_setosa.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count      48.000000     50.000000      49.000000      50.00000
# mean        5.022917      3.418000       1.465306       0.24400
# std         0.347171      0.381024       0.175061       0.10721
# min         4.300000      2.300000       1.000000       0.10000
# 25%         4.800000      3.125000       1.400000       0.20000
# 50%         5.000000      3.400000       1.500000       0.20000
# 75%         5.200000      3.675000       1.600000       0.30000
# max         5.800000      4.400000       1.900000       0.60000

# %%
df_versicolor = df_original[df_original["Species"] == "Iris-versicolor"]
df_versicolor.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count      50.000000     50.000000      49.000000     50.000000
# mean        5.936000      2.770000       4.271429      1.326000
# std         0.516171      0.313798       0.467707      0.197753
# min         4.900000      2.000000       3.000000      1.000000
# 25%         5.600000      2.525000       4.000000      1.200000
# 50%         5.900000      2.800000       4.400000      1.300000
# 75%         6.300000      3.000000       4.600000      1.500000
# max         7.000000      3.400000       5.100000      1.800000

# %%
df_virginica = df_original[df_original["Species"] == "Iris-virginica"]
df_virginica.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count      49.000000     50.000000      49.000000      50.00000
# mean        6.561224      2.974000       5.546939       2.02600
# std         0.613330      0.322497       0.556440       0.27465
# min         4.900000      2.200000       4.500000       1.40000
# 25%         6.200000      2.800000       5.100000       1.80000
# 50%         6.500000      3.000000       5.500000       2.00000
# 75%         6.900000      3.175000       5.900000       2.30000
# max         7.700000      3.800000       6.900000       2.50000

# %%
import matplotlib.pyplot as plt

def plotar_scatter(coluna):
    # Média de todas as notas
    media_setosa = df_setosa[coluna].mean()
    media_versicolor = df_versicolor[coluna].mean()
    media_virginica = df_virginica[coluna].mean()

    # Configuração do gráfico
    plt.figure(figsize=(10, 6))

    medias = [media_setosa, media_versicolor, media_virginica]
    nomes = ["Setosa", "Versicolor", "Virginica"]
    marcadores = ["o", "x", "s"]
    cores = ["red", "blue", "green"]

    for idx, data_frame in enumerate([df_setosa, df_versicolor, df_virginica]):
        # Plotando conjuntos dados de dispersão
        plt.scatter(
            data_frame.index,               # eixo X = índice
            data_frame[coluna],    # eixo Y = nota
            label=nomes[idx],               # Legenda
            marker=marcadores[idx],          # Tamanho do marcador
            color=cores[idx]
        )

        # Linha da média
        plt.axhline(
            y=medias[idx],
            linestyle="--",
            label=f"Média = {medias[idx]:.2f}",
            color=cores[idx]
        )

    # Título
    plt.title(f"Valores de {coluna}")

    # Nome dos eixos
    plt.xlabel("Índice da amostra")
    plt.ylabel(f"Tamanho de {coluna}")

    # Colocar grade
    plt.grid(True)

    # Gerar legenda
    plt.legend()

    # Exibir gráfico
    plt.show()

# %%
plotar_scatter("SepalLengthCm")

# %%
plotar_scatter("SepalWidthCm")

# %%
plotar_scatter("PetalLengthCm")

# %%
plotar_scatter("PetalWidthCm")

# %%
df_array = [df_setosa, df_versicolor, df_virginica]
cols_array = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

for data_frame in df_array:
    for col in cols_array:

        media = data_frame[col].mean()
        desvio_padrao = data_frame[col].std(ddof=0)

        data_frame[f"z_{col}"] = (data_frame[col] - media) / desvio_padrao

        q1 = data_frame[col].quantile(0.25)
        q3 = data_frame[col].quantile(0.75)
        iqr = q3 - q1

        limite_inferior = q1 - 1.5 * iqr
        limite_superior = q3 + 1.5 * iqr

        data_frame[f"oiqr_{col}"] = (
            (data_frame[col] < limite_inferior) |
            (data_frame[col] > limite_superior)
        )

# %%
outlier_zscore = []
outlier_iqr = []
for col in cols_array:
    outlier_zscore.append(f"z_{col}")
    outlier_iqr.append(f"oiqr_{col}")

# %%
out_setosa = df_setosa.loc[(df_setosa["oiqr_SepalLengthCm"] == True) |
                            (df_setosa["oiqr_SepalWidthCm"] == True) |
                            (df_setosa["oiqr_PetalLengthCm"] == True) |
                            (df_setosa["oiqr_PetalWidthCm"] == True)]

out_setosa
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 22            4.6           3.6            1.0           0.2  Iris-setosa
# 23            5.1           3.3            1.7           0.5  Iris-setosa
# 43            5.0           3.5            1.6           0.6  Iris-setosa
#
#     z_SepalLengthCm  oiqr_SepalLengthCm  z_SepalWidthCm  oiqr_SepalWidthCm  \
# 22        -1.231072               False        0.482509              False
# 23         0.224383               False       -0.312836              False
# 43        -0.066708               False        0.217394              False
#
#     z_PetalLengthCm  oiqr_PetalLengthCm  z_PetalWidthCm  oiqr_PetalWidthCm
# 22        -2.685514                True       -0.414578              False
# 23         1.354536               False        2.412091               True
# 43         0.777386               False        3.354314               True

# %%
out_versicolor = df_versicolor.loc[(df_versicolor["oiqr_SepalLengthCm"] == True) |
                            (df_versicolor["oiqr_SepalWidthCm"] == True) |
                            (df_versicolor["oiqr_PetalLengthCm"] == True) |
                            (df_versicolor["oiqr_PetalWidthCm"] == True)]

out_versicolor
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species  \
# 98            5.1           2.5            3.0           1.1  Iris-versicolor
#
#     z_SepalLengthCm  oiqr_SepalLengthCm  z_SepalWidthCm  oiqr_SepalWidthCm  \
# 98        -1.636061               False       -0.869161              False
#
#     z_PetalLengthCm  oiqr_PetalLengthCm  z_PetalWidthCm  oiqr_PetalWidthCm
# 98          -2.7466                True       -1.154444              False

# %%
out_virginica = df_virginica.loc[(df_virginica["oiqr_SepalLengthCm"] == True) |
                            (df_virginica["oiqr_SepalWidthCm"] == True) |
                            (df_virginica["oiqr_PetalLengthCm"] == True) |
                            (df_virginica["oiqr_PetalWidthCm"] == True)]

out_virginica
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species  \
# 106            4.9           2.5            4.5           1.7  Iris-virginica
# 117            7.7           3.8            6.7           2.2  Iris-virginica
# 119            6.0           2.2            5.0           1.5  Iris-virginica
# 131            NaN           3.8            6.4           2.0  Iris-virginica
#
#      z_SepalLengthCm  oiqr_SepalLengthCm  z_SepalWidthCm  oiqr_SepalWidthCm  \
# 106        -2.736602                True       -1.484705              False
# 117         1.875951               False        2.587270               True
# 119        -0.924528               False       -2.424391               True
# 131              NaN               False        2.587270               True
#
#      z_PetalLengthCm  oiqr_PetalLengthCm  z_PetalWidthCm  oiqr_PetalWidthCm
# 106        -1.900991               False       -1.199016              False
# 117         2.093684               False        0.639965              False
# 119        -0.993110               False       -1.934608              False
# 131         1.548956               False       -0.095627              False

# %%
outlier_array = [out_setosa, out_versicolor, out_virginica]

def plotar_scatter_outlier(coluna):
    # Média de todas as notas
    media_setosa = df_setosa[coluna].mean()
    media_versicolor = df_versicolor[coluna].mean()
    media_virginica = df_virginica[coluna].mean()

    # Configuração do gráfico
    plt.figure(figsize=(10, 6))

    medias = [media_setosa, media_versicolor, media_virginica]
    nomes = ["Setosa", "Versicolor", "Virginica"]
    marcadores = ["o", "x", "s"]
    cores = ["red", "blue", "green"]

    for idx, data_frame in enumerate([df_setosa, df_versicolor, df_virginica]):
        # Plotando conjuntos dados de dispersão
        plt.scatter(
            data_frame.index,               # eixo X = índice
            data_frame[coluna],    # eixo Y = nota
            label=nomes[idx],               # Legenda
            marker=marcadores[idx],          # Tamanho do marcador
            color=cores[idx]
        )

        plt.scatter(
            outlier_array[idx].index,               # eixo X = índice
            outlier_array[idx][coluna],    # eixo Y = nota
            label="Outlier",               # Legenda
            marker="^",          # Tamanho do marcador
            color="purple",
            s=80
        )

        # Linha da média
        plt.axhline(
            y=medias[idx],
            linestyle="--",
            label=f"Média = {medias[idx]:.2f}",
            color=cores[idx]
        )

    # Título
    plt.title(f"Valores de {coluna}")

    # Nome dos eixos
    plt.xlabel("Índice da amostra")
    plt.ylabel(f"Tamanho de {coluna}")

    # Colocar grade
    plt.grid(True)

    # Gerar legenda
    # plt.legend()

    # Exibir gráfico
    plt.show()

# %%
plotar_scatter_outlier("SepalLengthCm")

# %%
plotar_scatter_outlier("SepalWidthCm")

# %%
plotar_scatter_outlier("PetalLengthCm")

# %%
plotar_scatter_outlier("PetalWidthCm")

# %%
df_original.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='str')
