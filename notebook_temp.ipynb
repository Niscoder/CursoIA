# %%
arr = [ i for i in range(10)]

print(arr)

# %%
mystr = "um texto"
print(mystr)

mystr = 'um "texto"'
print(mystr)

mystr = "um 'texto'"
print(mystr)

# %%
str1 = "um"
str2 = " texto"

print(str1 + str2)

# %%
val = 5

mystr = f"o valor é: {val}"

print(mystr)

# %%
val = 6

mystr = f"o número é par? {"sim" if val % 2 == 0 else "não"}"

print(mystr)

# %%
mystr = "um texto"

print(mystr[0])
print(mystr[0:2])

# %%
mystr = "uM TeXto"

print(mystr.lower())
print(mystr.upper())

# %%
mystr = "uM TeXto"

print(mystr.split())

# %%
mystr = "uM-TeXto-novamente"

print(mystr.split('-'))

# %%
mystr = "uM- TeXto- novamente"

print(mystr.split(('- ')))

# %%
path = "meu_arquivo.txt"

print(path[:-4])
print(path.split('.txt'))
print(path.split('.txt')[0])

paths = path.split('.')
print(paths[0])
print(paths[1])

# %%
path = "meu_arquivo.txt"

print(path.removesuffix('.txt'))
print(path.removeprefix('meu'))

# %%
path = "meu_arquivo.txt"

print(path.capitalize())
print(path.find('arquivo'))
print(path.replace('meu', 'nosso'))

# %%
path = "Oi\nTudo\tbem?"

print(path)

# %%
path = "\n  Oi Tudo bem?  "

print(path.strip())

# %%
arr = [5,6,2,8,1]

arr.sort()

print(arr)

# %%
arr = ["Pedro", "João", "André"]

arr.sort()

print(arr)

# %%
mystr = "20"

print(type(mystr))

myint = int(mystr)

print(type(myint))

# %%
aluno = {"nome": "João", "nota": 10}

aluno["nome"] = "Pedro"
aluno["nota"] = 10.4

print(aluno["nome"])
print(aluno["nota"])

# %%
aluno = {"nome": "Pedro", "notas": [8, 9, 10]}

print(aluno)
print(aluno["notas"][1])

# %%
aluno = {"nome": "Pedro", "notas": {"geo": 8, "mat": 9, "lp": 10}}

print(aluno)
print(aluno["notas"]["mat"])

# %%
aluno = {"nome": "Pedro", "notas": {"geo": 8, "mat": 9}, "apro": True}

print(aluno)
del aluno["apro"]

print(aluno)

del aluno["notas"]["geo"]
print(aluno)

# %%
aluno = {"nome": "Pedro", "notas": {"geo": 8, "mat": 9, "lp": 10}}

aluno["aprov"] = True
print(aluno)

# %%
aluno = {"nome": "Pedro", "notas": [8, 9, 10]}

aluno["notas"][1] = 10

print(aluno)

# %%
mydict = {"nome": "João", "nota": 10}

print(mydict.pop("nota"))
print(mydict)

# %%
aluno = {
    "nome": "Gabriel",
    "idade": 25,
    "curso": "Computação"
}

for chave in aluno:
    print(aluno[chave])

# %%
mytuple = (10)

type(mytuple)

# %%
aluno = {
    "nome": "Gabriel",
    "idade": 25
}

print(aluno.values())

# %%
mylist = ["Gabriel", "Maria", "João", "José"]

for pessoa in mylist:
    print(pessoa)

# %%
aluno_s = ["Gabriel", "Maria", "João", "José"]
nota_s = [9, 8, 8, 10]

for idx in range(len(nota_s)):
    print(aluno_s[idx])
    print(nota_s[idx])
