# %%
import pandas as pd
import matplotlib.pyplot as plt

data_frame = pd.read_csv('dados_limpos.csv')

# %%
data_frame.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   idade         40 non-null     int64
#  1   universidade  40 non-null     str
#  2   curso         40 non-null     str
#  3   periodo       40 non-null     int64
#  4   ling_prog     40 non-null     str
#  5   area_atuacao  40 non-null     str
#  6   art_banda     40 non-null     str
#  7   filme_serie   40 non-null     str
#  8   comida_fav    40 non-null     str
#  9   hobby         40 non-null     str
#  10  atv_fisica    40 non-null     bool
#  11  altura        40 non-null     int64
# dtypes: bool(1), int64(3), str(8)
# memory usage: 3.6 KB

# %%
data_frame.head()
# Out:
#    idade           universidade                   curso  periodo   ling_prog  \
# 0     23                 unifil   ciencia da computacao        7  javascript
# 1     24                    puc                     ads        5  javascript
# 2     20                 unifil  engenharia de software        2         php
# 3     30                 unifil   ciencia da computacao        4        java
# 4     21  universidade positivo  engenharia de software        7      python
#
#        area_atuacao art_banda        filme_serie comida_fav    hobby  \
# 0               dev       pop           fantasia     lanche    jogos
# 1  ciencia_dados/ia       rap           fantasia   japonesa    artes
# 2  gestao/diretoria       pop           fantasia      massa    artes
# 3  ciencia_dados/ia      rock  ficção científica      massa  esporte
# 4  ciencia_dados/ia      rock              drama      massa    jogos
#
#    atv_fisica  altura
# 0        True     175
# 1       False     168
# ...

# %%
data_frame.describe()
# Out:
#            idade    periodo      altura
# count  40.000000  40.000000   40.000000
# mean   21.525000   4.625000  174.425000
# std     2.800984   1.612253    8.664361
# min    18.000000   2.000000  150.000000
# 25%    20.000000   4.000000  168.750000
# 50%    21.000000   5.000000  175.000000
# 75%    23.000000   6.000000  180.000000
# max    32.000000   8.000000  198.000000

# %%
data_frame.isna().sum()
# Out:
# idade           0
# universidade    0
# curso           0
# periodo         0
# ling_prog       0
# area_atuacao    0
# art_banda       0
# filme_serie     0
# comida_fav      0
# hobby           0
# atv_fisica      0
# altura          0
# dtype: int64

# %%
data_frame = data_frame.sort_values("periodo", ascending=True)

# %%
data_frame.head()
# Out:
#     idade           universidade                   curso  periodo ling_prog  \
# 2      20                 unifil  engenharia de software        2       php
# 7      19                    uel   ciencia de dados e IA        2    python
# 15     22                    uel   ciencia de dados e IA        2    python
# 11     22                  utfpr  sistemas de informacao        2    python
# 30     19  universidade positivo                     ads        2    python
#
#         area_atuacao art_banda        filme_serie comida_fav    hobby  \
# 2   gestao/diretoria       pop           fantasia      massa    artes
# 7                n/d       pop  ficção científica     outros    jogos
# 15  ciencia_dados/ia      rock              drama     lanche  esporte
# 11  gestao/diretoria       rap           fantasia  churrasco    artes
# 30               n/d      rock              drama     lanche    jogos
#
#     atv_fisica  altura
# 2        False     166
# 7         True     177
# ...

# %%
data_frame.tail()
# Out:
#     idade           universidade                   curso  periodo   ling_prog  \
# 26     21               unisenai  engenharia de software        6        java
# 38     19                 unifil  engenharia de software        6        java
# 0      23                 unifil   ciencia da computacao        7  javascript
# 4      21  universidade positivo  engenharia de software        7      python
# 9      21                  utfpr  engenharia de software        8  javascript
#
#         area_atuacao art_banda filme_serie comida_fav    hobby  atv_fisica  \
# 26               dev      rock    fantasia     lanche    jogos       False
# 38  ciencia_dados/ia       rap    fantasia  churrasco  esporte        True
# 0                dev       pop    fantasia     lanche    jogos        True
# 4   ciencia_dados/ia      rock       drama      massa    jogos       False
# 9                n/d    outros    fantasia      massa    jogos       False
#
#     altura
# 26     161
# 38     178
# ...

# %%
data_frame["periodo"].value_counts()
# Out:
# periodo
# 6    12
# 4    11
# 2     7
# 5     6
# 7     2
# 3     1
# 8     1
# Name: count, dtype: int64

# %%
pd.DataFrame(data_frame.groupby("curso")["periodo"].value_counts())
# Out:
#                                   count
# curso                    periodo
# ads                      2            2
#                          4            2
#                          5            2
#                          6            1
# ciencia da computacao    6            3
#                          4            1
#                          7            1
# ciencia de dados e IA    2            2
#                          4            1
# engenharia de software   6            8
#                          5            4
#                          4            3
#                          2            1
#                          7            1
#                          8            1
# mestrado em eng elétrica 4            1
# sistemas de informacao   4            3
#                          2            2
#                          3            1

# %%
data_resultado = pd.crosstab(data_frame["curso"], data_frame["periodo"])

data_resultado
# Out:
# periodo                   2  3  4  5  6  7  8
# curso
# ads                       2  0  2  2  1  0  0
# ciencia da computacao     0  0  1  0  3  1  0
# ciencia de dados e IA     2  0  1  0  0  0  0
# engenharia de software    1  0  3  4  8  1  1
# mestrado em eng elétrica  0  0  1  0  0  0  0
# sistemas de informacao    2  1  3  0  0  0  0

# %%
data_resultado = pd.crosstab(data_frame["curso"], data_frame["area_atuacao"])

data_resultado
# Out:
# area_atuacao              ciencia_dados/ia  dev  gestao/diretoria  n/d
# curso
# ads                                      3    1                 2    1
# ciencia da computacao                    4    1                 0    0
# ciencia de dados e IA                    2    0                 0    1
# engenharia de software                  10    4                 2    2
# mestrado em eng elétrica                 0    0                 1    0
# sistemas de informacao                   4    1                 1    0

# %%
data_resultado = pd.crosstab(data_frame["curso"], data_frame["universidade"])

data_resultado
# Out:
# universidade              puc  uel  unicesumar  unifil  unisenai  \
# curso
# ads                         2    0           3       1         0
# ciencia da computacao       0    0           0       5         0
# ciencia de dados e IA       0    3           0       0         0
# engenharia de software      0    0           0      12         2
# mestrado em eng elétrica    0    0           0       0         0
# sistemas de informacao      0    0           0       0         0
#
# universidade              universidade positivo  utfpr
# curso
# ads                                           1      0
# ciencia da computacao                         0      0
# ciencia de dados e IA                         0      0
# engenharia de software                        2      2
# mestrado em eng elétrica                      0      1
# sistemas de informacao                        0      6

# %%
data_frame["idade"].describe()
# Out:
# count    40.000000
# mean     21.525000
# std       2.800984
# min      18.000000
# 25%      20.000000
# 50%      21.000000
# 75%      23.000000
# max      32.000000
# Name: idade, dtype: float64

# %%
# DataFrame com uma coluna de índice para facilitar o plot de gráficos
data_plot = data_frame.reset_index()

# %%
data_frame.boxplot(column="idade")
plt.show()

# %%
data_plot.plot.scatter(x="index", y="idade")
plt.show()

# %%
data_frame["altura"].describe()
# Out:
# count     40.000000
# mean     174.425000
# std        8.664361
# min      150.000000
# 25%      168.750000
# 50%      175.000000
# 75%      180.000000
# max      198.000000
# Name: altura, dtype: float64

# %%
data_plot.boxplot(column="altura")
plt.show()

# %%
data_plot.plot.scatter(x="index", y="altura")
plt.show()

# %%
data_frame["periodo"].describe()
# Out:
# count    40.000000
# mean      4.625000
# std       1.612253
# min       2.000000
# 25%       4.000000
# 50%       5.000000
# 75%       6.000000
# max       8.000000
# Name: periodo, dtype: float64

# %%
data_plot.boxplot(column="periodo")
plt.show()

# %%
data_plot.plot.scatter(x="index", y="periodo")
plt.show()

# %%
data_plot["periodo"].value_counts(sort=False).plot(kind="bar")

plt.show()
