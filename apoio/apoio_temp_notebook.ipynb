# %%
var1 = "nome"
var2 = 2
var3 = 40.5
var4 = True #False
var5 = None

var2 = 3

print(var1, var2, var3, var4, var5)
# Out:
# nome 3 40.5 True None

# %%
var2 = 1
var3 = 2

resultado = var2 + 7 * var3 + 5
resultado2 = ((var2 + 7) * var3) + 5
print(resultado)
print(resultado2)
# Out:
# 20
# 21

# %%
print("oi")

if True: #condição
    #bloco de código quando condição ser verdadeira
    print("deu certo!")
    if True:
        print("deu certo 2!")
        if False:
            print("deu certo 4!")
    print("deu certo 3!")
# Out:
# oi
# deu certo!
# deu certo 2!
# deu certo 3!

# %%
print("oi")

if True: #condição
    print("é verdadeiro!")
else:
    print("é falso!")
# Out:
# oi
# é verdadeiro!

# %%
if False: #condição
    print("é verdadeiro 1!")
elif True:
    print("é verdadeiro 2!")
else:
    print("é false")
# Out:
# é verdadeiro 2!

# %%
print(3 == 3)
print(3 != 3)
print(3 >= 3)
print(3 <= 3)
print(3 > 3)
print(3 < 3)

resto = 10 % 2
print(resto == 0)
# Out:
# True
# False
# True
# True
# False
# False
# True
